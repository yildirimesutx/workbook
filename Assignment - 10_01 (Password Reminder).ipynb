# %%
password = int(input("Enter password: "))

password_key = 123456

if password_key == password :
   print("Hello, Mesut! The password: 123456")
else:
  print("Hello, Mesut! See you later...")
# Out:
# Enter password: 125896
# Hello, Mesut! See you later...
